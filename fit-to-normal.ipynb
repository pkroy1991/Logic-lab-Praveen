# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
mu = 10
sigma = 100
s = np.random.normal(mu, sigma, 100)
np.savetxt('dataset-two.txt', s)

# %%
plt.hist(s, bins=20, color='skyblue', edgecolor='black')
# Out:
# (array([ 1.,  0.,  0.,  1.,  3.,  4.,  3.,  7., 11., 13., 14., 15.,  7.,
#          8.,  6.,  5.,  1.,  0.,  0.,  1.]),
#  array([-355.16921478, -320.54679767, -285.92438057, -251.30196346,
#         -216.67954635, -182.05712925, -147.43471214, -112.81229504,
#          -78.18987793,  -43.56746083,   -8.94504372,   25.67737339,
#           60.29979049,   94.9222076 ,  129.5446247 ,  164.16704181,
#          198.78945892,  233.41187602,  268.03429313,  302.65671023,
#          337.27912734]),
#  <BarContainer object of 20 artists>)

# %%
np.mean(s)
# Out:
# 5.503125937150323

# %%
np.median(s)
# Out:
# 11.731214150546986

# %%
stats.trim_mean(s,.4)
# Out:
# 7.8215141654924

# %%
np.std(s)
# Out:
# 108.7936683704205

# %%
stats.probplot(s, dist="norm", plot=plt)
plt.title('Normal Q-Q plot')
plt.xlabel('Theoretical quantiles')
plt.ylabel('Ordered Values')
plt.grid(True)
plt.show()

# %%
mu = 10
sigma = 1000
s = np.random.normal(mu, sigma, 10000)
np.savetxt('dataset-one.txt', s)

# %%
plt.hist(s, bins=20, color='skyblue', edgecolor='black')
# Out:
# (array([1.000e+00, 4.000e+00, 1.600e+01, 4.400e+01, 1.360e+02, 2.620e+02,
#         5.810e+02, 9.360e+02, 1.325e+03, 1.493e+03, 1.581e+03, 1.429e+03,
#         9.580e+02, 6.470e+02, 3.440e+02, 1.570e+02, 6.000e+01, 1.500e+01,
#         8.000e+00, 3.000e+00]),
#  array([-4019.10390501, -3621.11965878, -3223.13541255, -2825.15116632,
#         -2427.16692009, -2029.18267387, -1631.19842764, -1233.21418141,
#          -835.22993518,  -437.24568895,   -39.26144272,   358.72280351,
#           756.70704974,  1154.69129597,  1552.6755422 ,  1950.65978843,
#          2348.64403466,  2746.62828089,  3144.61252712,  3542.59677335,
#          3940.58101958]),
#  <BarContainer object of 20 artists>)

# %%
np.mean(s)
# Out:
# 4.863010495882128

# %%
np.median(s)
# Out:
# 12.544531774241872

# %%
stats.probplot(s, dist="norm", plot=plt)
plt.title('Normal Q-Q plot')
plt.xlabel('Theoretical quantiles')
plt.ylabel('Ordered Values')
plt.grid(True)
plt.show()
