# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
mu = 10
sigma = 100
s = np.random.normal(mu, sigma, 100)
np.savetxt('dataset-two.txt', s)

# %%
plt.hist(s, bins=20, color='skyblue', edgecolor='black')
# Out:
# (array([ 1.,  0.,  0.,  1.,  8.,  6.,  9., 10.,  5., 16., 10.,  9.,  5.,
#          4.,  7.,  1.,  4.,  2.,  0.,  2.]),
#  array([-237.00113645, -213.34865603, -189.6961756 , -166.04369518,
#         -142.39121475, -118.73873433,  -95.08625391,  -71.43377348,
#          -47.78129306,  -24.12881264,   -0.47633221,   23.17614821,
#           46.82862863,   70.48110906,   94.13358948,  117.7860699 ,
#          141.43855033,  165.09103075,  188.74351118,  212.3959916 ,
#          236.04847202]),
#  <BarContainer object of 20 artists>)

# %%
np.mean(s)
# Out:
# np.float64(-4.745265962272033)

# %%
np.median(s)
# Out:
# np.float64(-8.395683882004127)

# %%
stats.trim_mean(s,.4)
# Out:
# np.float64(-6.976613036197297)

# %%
np.std(s)
# Out:
# np.float64(89.53884364791742)

# %%
stats.probplot(s, dist="norm", plot=plt)
plt.title('Normal Q-Q plot')
plt.xlabel('Theoretical quantiles')
plt.ylabel('Ordered Values')
plt.grid(True)
plt.show()

# %%
mu = 10
sigma = 1000
s = np.random.normal(mu, sigma, 10000)
np.savetxt('dataset-one.txt', s)

# %%
plt.hist(s, bins=20, color='skyblue', edgecolor='black')
# Out:
# (array([   3.,    2.,   13.,   59.,  149.,  344.,  671., 1051., 1331.,
#         1645., 1570., 1292.,  877.,  553.,  286.,  107.,   29.,   12.,
#            3.,    3.]),
#  array([-4059.19382327, -3646.0313376 , -3232.86885193, -2819.70636625,
#         -2406.54388058, -1993.38139491, -1580.21890924, -1167.05642357,
#          -753.8939379 ,  -340.73145223,    72.43103344,   485.59351911,
#           898.75600478,  1311.91849046,  1725.08097613,  2138.2434618 ,
#          2551.40594747,  2964.56843314,  3377.73091881,  3790.89340448,
#          4204.05589015]),
#  <BarContainer object of 20 artists>)

# %%
np.mean(s)
# Out:
# np.float64(5.704380943281073)

# %%
np.median(s)
# Out:
# np.float64(8.255754688297099)

# %%
stats.probplot(s, dist="norm", plot=plt)
plt.title('Normal Q-Q plot')
plt.xlabel('Theoretical quantiles')
plt.ylabel('Ordered Values')
plt.grid(True)
plt.show()
